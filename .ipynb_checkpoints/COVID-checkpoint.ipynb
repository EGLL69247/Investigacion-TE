# %% [markdown]
# # GIS con Python

# %% [markdown]
# ##### En el presente proyecto se muestra como es que podemos transformar datos en información espacial, con un caso practico en el que se analizan los datos covid actualizados hasta la fecha 26/08/21.
# ##### Como primer paso, importamos las librerías necesarias para el proyecto

# %% [markdown]
# ##### Pandas: Paquetería que nos permite trabajar con tablas de atributos
# ##### Geopandas: Paquetería que nos permite trabajar con las geometrias

# %%
import pandas as pd 
import geopandas as gpd
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# # Importación de datos
# ##### Para importar los datos aplicaremos dos métodos, uno directamente desde la página de "Datos Abiertos Dirección General de Epidemiología" y otro en el que cargamos los archivos desde la consola de comandos de anaconda

# %% [markdown]
# ![title](Base.png)

# %%
cv= pd.read_csv('http://datosabiertos.salud.gob.mx/gobmx/salud/datos_abiertos/datos_abiertos_covid19.zip', encoding= 'ISO-8859-1')
cv.head()
# Out:
# D:\Conda\envs\geo_env\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (38) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0          2021-09-21      z482b8       2      12           9     2
# 1          2021-09-21      z49a69       1      12          23     1
# 2          2021-09-21      z23d9d       1      12          22     2
# 3          2021-09-21      z24953       1      12           9     1
# 4          2021-09-21      zz8e77       2      12           9     2
#
#    ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ... OTRO_CASO  \
# 0            9            9             12              1  ...         2
# 1           23           23              4              2  ...         1
# 2           24           22              9              1  ...         2
# 3            9            9             10              1  ...         1
# 4            9            9              2              1  ...         2
#
#   TOMA_MUESTRA_LAB RESULTADO_LAB  TOMA_MUESTRA_ANTIGENO  RESULTADO_ANTIGENO  \
# 0                2            97                      2                  97
# 1                2            97                      2                  97
# 2                2            97                      2                  97
# 3                1             2                      2                  97
# 4                2            97                      2                  97
#
#    CLASIFICACION_FINAL  MIGRANTE  PAIS_NACIONALIDAD  PAIS_ORIGEN  UCI
# 0                    1        99            MÃ©xico           97   97
# 1                    2        99            MÃ©xico           97    1
# 2                    6        99            MÃ©xico           97   97
# 3                    7        99            MÃ©xico           97   97
# 4                    6        99            MÃ©xico           97   97
#
# [5 rows x 40 columns]

# %% [markdown]
# # Datos

# %% [markdown]
# ##### Mapearemos todos los datos que se tienen del covid-19 para el territorio de México, descargamos los mismos de la página de: https://www.gob.mx/salud/documentos/datos-abiertos-152127

# %% [markdown]
# ##### Ya podemos visualizar que nuestros datos carecen de geometría, atributo que vuelve nuestra información espacial; por lo que le asignaremos dicha info. de la siguiente manera:

# %% [markdown]
# # Datos Espaciales

# %% [markdown]
# #### Para continuar con la asignación de datos espaciales, debemos de entrar en la pagina web de la conabio y descargar el archivo shp de la división municipal de México; en este caso descargaremos la versión 2019 ya que es la más actualizada
#
# http://www.conabio.gob.mx/informacion/gis/
#
# #### Desde "anaconda prompt" se cargaron al script los archivos descargados

# %%
mun= gpd.read_file('mun2019gw.shp')

# %% [markdown]
# #### A continuación en el grafico podemos observar que los datos efectivamente se encuentran seccionados por entidad municipal y corresponden al área geográfica de México.

# %%
mun.plot(figsize=(10,10));

# %%
mun.head()
# Out:
#   CVEGEO CVE_ENT CVE_MUN         NOM_ENT           AREA   PERIMETER  COV_  \
# 0  01001      01     001  Aguascalientes  116635.924760  256.631026     0
# 1  01002      01     002  Aguascalientes   54337.426596  192.096428     1
# 2  01003      01     003  Aguascalientes   92335.783227  171.636168     2
# 3  01004      01     004  Aguascalientes   12838.354453   73.352682     3
# 4  01005      01     005  Aguascalientes   49989.509147  163.500810     4
#
#    COV_ID         NOM_MUN                                           geometry
# 0       1  Aguascalientes  POLYGON ((-102.09775 22.02325, -102.09857 22.0...
# 1       2        Asientos  POLYGON ((-102.06290 22.30175, -102.06267 22.3...
# 2       3        Calvillo  POLYGON ((-102.57625 21.96778, -102.57626 21.9...
# 3       4          CosÃ­o  POLYGON ((-102.25320 22.37449, -102.25320 22.3...
# 4       5   JesÃºs MarÃ­a  POLYGON ((-102.31034 22.03716, -102.31034 22.0...

# %% [markdown]
# # Base de Datos Espacial

# %% [markdown]
# ##### Ya tenemos cargados los atributos y las geometrías, lo que nos interesa es que cada geometría (polígono que define la entidad municipal) tenga su correspondiente elemento de la tabla de atributos; es decir que los datos de Aguascalientes caigan en el polígono de Aguascalientes y así sucesivamente para todos los municipios

# %%
cv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10408601 entries, 0 to 10408600
# Data columns (total 40 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   FECHA_ACTUALIZACION    object
#  1   ID_REGISTRO            object
#  2   ORIGEN                 int64
#  3   SECTOR                 int64
#  4   ENTIDAD_UM             int64
#  5   SEXO                   int64
#  6   ENTIDAD_NAC            int64
#  7   ENTIDAD_RES            int64
#  8   MUNICIPIO_RES          int64
#  9   TIPO_PACIENTE          int64
#  10  FECHA_INGRESO          object
#  11  FECHA_SINTOMAS         object
#  12  FECHA_DEF              object
#  13  INTUBADO               int64
#  14  NEUMONIA               int64
#  15  EDAD                   int64
#  16  NACIONALIDAD           int64
#  17  EMBARAZO               int64
#  18  HABLA_LENGUA_INDIG     int64
#  19  INDIGENA               int64
#  20  DIABETES               int64
#  21  EPOC                   int64
#  22  ASMA                   int64
#  23  INMUSUPR               int64
#  24  HIPERTENSION           int64
#  25  OTRA_COM               int64
#  26  CARDIOVASCULAR         int64
#  27  OBESIDAD               int64
#  28  RENAL_CRONICA          int64
#  29  TABAQUISMO             int64
#  30  OTRO_CASO              int64
#  31  TOMA_MUESTRA_LAB       int64
#  32  RESULTADO_LAB          int64
#  33  TOMA_MUESTRA_ANTIGENO  int64
#  34  RESULTADO_ANTIGENO     int64
#  35  CLASIFICACION_FINAL    int64
#  36  MIGRANTE               int64
#  37  PAIS_NACIONALIDAD      object
#  38  PAIS_ORIGEN            object
#  39  UCI                    int64
# dtypes: int64(33), object(7)
# memory usage: 3.1+ GB

# %%
mun.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 2483 entries, 0 to 2482
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   CVEGEO     2483 non-null   object
#  1   CVE_ENT    2483 non-null   object
#  2   CVE_MUN    2483 non-null   object
#  3   NOM_ENT    2483 non-null   object
#  4   AREA       2483 non-null   float64
#  5   PERIMETER  2483 non-null   float64
#  6   COV_       2483 non-null   int64
#  7   COV_ID     2483 non-null   int64
#  8   NOM_MUN    2483 non-null   object
#  9   geometry   2483 non-null   geometry
#  10  mrg        2483 non-null   object
# dtypes: float64(2), geometry(1), int64(2), object(6)
# memory usage: 213.5+ KB

# %% [markdown]
# # Transformar datos

# %% [markdown]
# #### Para poder realizar el join espacial entre atributos y geometrias, debemos de tener el mismo tipo de dato, no solo en la forma de correspondendcia tipo: Datos de Aguascalientes-Geometria de Aguascalientes.
#
# #### Se debe tener la correspondencia "str" a "str" o en su defecto "float" a "float" por lo que transformaremos los elementos de "ENTIDAD_RES" y "MUNICIPIO_RES" a "str" mediante una lista de comprención.

# %%
cv['mrg']= [str(i)+'-'+str(j) for i,j in zip(cv.ENTIDAD_RES,cv.MUNICIPIO_RES)];

# %%
cv.head()
# Out:
#   FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0          2021-09-21      z482b8       2      12           9     2
# 1          2021-09-21      z49a69       1      12          23     1
# 2          2021-09-21      z23d9d       1      12          22     2
# 3          2021-09-21      z24953       1      12           9     1
# 4          2021-09-21      zz8e77       2      12           9     2
#
#    ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ...  \
# 0            9            9             12              1  ...
# 1           23           23              4              2  ...
# 2           24           22              9              1  ...
# 3            9            9             10              1  ...
# 4            9            9              2              1  ...
#
#   TOMA_MUESTRA_LAB RESULTADO_LAB TOMA_MUESTRA_ANTIGENO  RESULTADO_ANTIGENO  \
# 0                2            97                     2                  97
# 1                2            97                     2                  97
# 2                2            97                     2                  97
# 3                1             2                     2                  97
# 4                2            97                     2                  97
#
#    CLASIFICACION_FINAL  MIGRANTE  PAIS_NACIONALIDAD  PAIS_ORIGEN  UCI   mrg
# 0                    1        99            MÃ©xico           97   97  9-12
# 1                    2        99            MÃ©xico           97    1  23-4
# 2                    6        99            MÃ©xico           97   97  22-9
# 3                    7        99            MÃ©xico           97   97  9-10
# 4                    6        99            MÃ©xico           97   97   9-2
#
# [5 rows x 41 columns]

# %%
mun.head()
# Out:
#   CVEGEO CVE_ENT CVE_MUN         NOM_ENT           AREA   PERIMETER  COV_  \
# 0  01001      01     001  Aguascalientes  116635.924760  256.631026     0
# 1  01002      01     002  Aguascalientes   54337.426596  192.096428     1
# 2  01003      01     003  Aguascalientes   92335.783227  171.636168     2
# 3  01004      01     004  Aguascalientes   12838.354453   73.352682     3
# 4  01005      01     005  Aguascalientes   49989.509147  163.500810     4
#
#    COV_ID         NOM_MUN                                           geometry
# 0       1  Aguascalientes  POLYGON ((-102.09775 22.02325, -102.09857 22.0...
# 1       2        Asientos  POLYGON ((-102.06290 22.30175, -102.06267 22.3...
# 2       3        Calvillo  POLYGON ((-102.57625 21.96778, -102.57626 21.9...
# 3       4          CosÃ­o  POLYGON ((-102.25320 22.37449, -102.25320 22.3...
# 4       5   JesÃºs MarÃ­a  POLYGON ((-102.31034 22.03716, -102.31034 22.0...

# %%
mun['mrg']= [str(int(i))+'-'+str(int(j)) for i,j in zip(mun.CVE_ENT,mun.CVE_MUN)];

# %%
mun.head()
# Out:
#   CVEGEO CVE_ENT CVE_MUN         NOM_ENT           AREA   PERIMETER  COV_  \
# 0  01001      01     001  Aguascalientes  116635.924760  256.631026     0
# 1  01002      01     002  Aguascalientes   54337.426596  192.096428     1
# 2  01003      01     003  Aguascalientes   92335.783227  171.636168     2
# 3  01004      01     004  Aguascalientes   12838.354453   73.352682     3
# 4  01005      01     005  Aguascalientes   49989.509147  163.500810     4
#
#    COV_ID         NOM_MUN                                           geometry  \
# 0       1  Aguascalientes  POLYGON ((-102.09775 22.02325, -102.09857 22.0...
# 1       2        Asientos  POLYGON ((-102.06290 22.30175, -102.06267 22.3...
# 2       3        Calvillo  POLYGON ((-102.57625 21.96778, -102.57626 21.9...
# 3       4          CosÃ­o  POLYGON ((-102.25320 22.37449, -102.25320 22.3...
# 4       5   JesÃºs MarÃ­a  POLYGON ((-102.31034 22.03716, -102.31034 22.0...
#
#    mrg
# 0  1-1
# 1  1-2
# 2  1-3
# 3  1-4
# 4  1-5

# %% [markdown]
# # Transformamos la base de datos covid en una base espacial

# %%
mu= mun[['mrg','geometry']];
mu
# Out:
#          mrg                                           geometry
# 0        1-1  POLYGON ((-102.09775 22.02325, -102.09857 22.0...
# 1        1-2  POLYGON ((-102.06290 22.30175, -102.06267 22.3...
# 2        1-3  POLYGON ((-102.57625 21.96778, -102.57626 21.9...
# 3        1-4  POLYGON ((-102.25320 22.37449, -102.25320 22.3...
# 4        1-5  POLYGON ((-102.31034 22.03716, -102.31034 22.0...
# ...      ...                                                ...
# 2478  20-183  POLYGON ((-98.36473 17.58262, -98.36356 17.582...
# 2479    19-7  POLYGON ((-99.62021 24.27840, -99.60523 24.308...
# 2480   28-16  POLYGON ((-99.62021 24.27840, -99.60523 24.308...
# 2481   24-10  POLYGON ((-99.63617 22.66566, -99.66599 22.675...
# 2482   28-39  POLYGON ((-99.63617 22.66566, -99.66599 22.675...
#
# [2483 rows x 2 columns]

# %%
gcv= pd.merge(cv,mu,on= 'mrg')

# %%
len(cv)
# Out:
# 10408601

# %%
len(gcv)
# Out:
# 10903503

# %%
gpd.GeoDataFrame(gcv);

# %% [markdown]
# ### CLASIFICACION_FINAL	 nos muestra los casos positivos con la clave "3" y negativos con la clave "7"

# %%
pos= gcv[gcv.CLASIFICACION_FINAL==3]

# %%
pos.head()
# Out:
#     FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 4            2021-09-21      z526b3       2      12           9     1
# 5            2021-09-21      z526b3       2      12           9     1
# 638          2021-09-21      0c0d9c       1      12          12     2
# 639          2021-09-21      0c0d9c       1      12          12     2
# 860          2021-09-21      1df36e       1      12           9     2
#
#      ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ...  \
# 4              9            9             12              1  ...
# 5              9            9             12              1  ...
# 638           28            9             12              1  ...
# 639           28            9             12              1  ...
# 860           15            9             12              1  ...
#
#     RESULTADO_LAB TOMA_MUESTRA_ANTIGENO RESULTADO_ANTIGENO  \
# 4              97                     1                  1
# 5              97                     1                  1
# 638             1                     2                 97
# 639             1                     2                 97
# 860             1                     2                 97
#
#      CLASIFICACION_FINAL  MIGRANTE  PAIS_NACIONALIDAD  PAIS_ORIGEN  UCI   mrg  \
# 4                      3        99            MÃ©xico           97   97  9-12
# 5                      3        99            MÃ©xico           97   97  9-12
# 638                    3        99            MÃ©xico           97   97  9-12
# 639                    3        99            MÃ©xico           97   97  9-12
# 860                    3        99            MÃ©xico           97   97  9-12
#
#                                               geometry
# 4    POLYGON ((-99.20575 19.30568, -99.20567 19.305...
# 5    POLYGON ((-99.28761 19.14660, -99.29312 19.165...
# 638  POLYGON ((-99.20575 19.30568, -99.20567 19.305...
# 639  POLYGON ((-99.28761 19.14660, -99.29312 19.165...
# 860  POLYGON ((-99.20575 19.30568, -99.20567 19.305...
#
# [5 rows x 42 columns]

# %%
pos= pos['mrg'].value_counts().reset_index()
pos.rename(columns={'index':'mrg','mrg':'cnt'},inplace=True)

# %%
pd.merge(pos,mu,on= 'mrg')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-72dd9bb2ae0f> in <module>
# ----> 1 pd.merge(pos,mu,on= 'mrg')
#
# D:\Conda\envs\geo_env\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      72     validate=None,
#      73 ) -> "DataFrame":
# ---> 74     op = _MergeOperation(
#      75         left,
#      76         right,
#
# D:\Conda\envs\geo_env\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     670         # validate the merge keys dtypes. We may need to coerce
#     671         # to avoid incompatible dtypes
# --> 672         self._maybe_coerce_merge_keys()
#     673
#     674         # If argument passed to validate,
#
# D:\Conda\envs\geo_env\lib\site-packages\pandas\core\reshape\merge.py in _maybe_coerce_merge_keys(self)
#    1191                     inferred_right in string_types and inferred_left not in string_types
#    1192                 ):
# -> 1193                     raise ValueError(msg)
#    1194
#    1195             # datetimelikes must match exactly
#
# ValueError: You are trying to merge on int64 and object columns. If you wish to proceed you should use pd.concat

# %%
pos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 861 entries, 0 to 860
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   index   861 non-null    int64
#  1   mrg     861 non-null    int64
# dtypes: int64(2)
# memory usage: 13.6 KB

# %%
mu.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 2483 entries, 0 to 2482
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   mrg       2483 non-null   object
#  1   geometry  2483 non-null   geometry
# dtypes: geometry(1), object(1)
# memory usage: 38.9+ KB
